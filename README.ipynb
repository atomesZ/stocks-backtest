# %%
# %load_ext autoreload
# %autoreload 2

from backtest import Backtest
from backtest_comparator import BacktestComparator

# %% [markdown]
# # How to get the CSV
# - Go to yahoo finance and either download historical data or copy paste

# %%
sp500 = Backtest("csv_data/sp500.csv", is_copy_pasted_csv=True)
ndx = Backtest("csv_data/^NDX.csv")

comparator = BacktestComparator([sp500, ndx])

# %%
# Visualize the evolution of the stocks
comparator.plot()

# %%
# Simulate and compare a DCA investing on both stocks
comparator.plot_DCA(monthly_invested=1000)
